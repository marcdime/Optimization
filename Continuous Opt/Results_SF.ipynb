# %% [markdown]
# ## F1 : shifted sphere

# %%
from main import *
import shift as sf

#Visualisation with a 2D-vector
f1 = shifted_sphere(2, sf.sphere,sf.f_bias[0])
viz_2dim(x_range = 100, y_range = 100, step = 10, prob_instance = f1)

# %%
# Looking for the "best" algorithm with a 10-Dim vector (to reduce the computation time)
f1.dim = 10
run_algos(prob_instance = f1, generations = 200, num_individuals_pop = 30)

# %% [markdown]
# ### Dimension = 50

# %%
# Running the "best" algorithm and displaying the performance
f1.dim = 50
run_pso(prob_instance = f1, epoch_runs = 10, generations = 500, 
        inertia = 0.7, 
        self_confidence = 2.0,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Sphere Function
# Dimension : 50
# Best solution vector :
#  [ 97.29236883  77.03832139 -19.01843562  25.42881393 -22.81127691
#   69.55278895   5.39784844  61.50776594 -21.28725256  92.34267455
#  -93.94963574  90.72437844  42.8505827   29.27768829 -10.73886032
#  -65.05013337  67.07670675  94.05082065 -73.03907543 -49.73135693
#   82.02135085  35.31810413  24.65062578   2.45961095 -99.35694877
#  -54.59376166  95.64292945  72.2548533  -97.0476838   -2.7608235
#  -16.73835364  54.615254    -2.32472703   4.51835595  56.43200892
#   18.20564197 -74.76460184 -78.01474264  32.56471918  99.3607616
#  -30.77582883 -64.78470346 -86.45887917 -38.15099357 -33.04610114
#  -24.7776587   90.45485357  43.77723301  55.92264523  23.51812778]
# Best fitness : [-449.92293045]
# Time of calculation of the best run : 0:00:05.493268
# Total time of calculation (over 10 runs) : 0:01:03.754891

# %%
# Tuning the parameters
run_pso(prob_instance = f1, epoch_runs = 10, generations = 500, 
        inertia = 0.4, 
        self_confidence = 2.0,
        swarm_confidence = 2.4, num_individuals_pop = 30)
# Out:
# Problem : Shifted Sphere Function
# Dimension : 50
# Best solution vector :
#  [ 99.92068211  72.66153409 -20.14112773  25.57112272 -24.26722578
#   68.13736782   4.99248982  60.05332701 -21.20966614  93.26549431
#  -92.7617976   90.9235582   40.24427248  26.01051769 -10.17543305
#  -59.07833155  63.95152152  96.46121249 -77.3868811  -50.2318073
#   81.34080228  35.36515236  21.83471047  16.96322725 -98.77095592
#  -55.64683051  95.12267106  77.40140359 -97.38291722  -4.16938687
#  -15.75507338  50.08158264  -4.82556963   5.30639028  60.37832789
#   17.9017151  -76.26865462 -77.89479526  32.67406823  99.38102765
#  -30.45842935 -74.78281355 -86.55045152 -38.50974911 -32.97421998
#  -25.70730667  87.8003924   54.51390843  57.66789757  23.63864083]
# Best fitness : [195.04852983]
# Time of calculation of the best run : 0:00:05.588530
# Total time of calculation (over 10 runs) : 0:00:57.747785

# %%
# A test with Genetic Algorithm with the same dimension (D = 50)
run_sga(prob_instance = f1, epoch_runs = 10, generations = 500, num_individuals_pop = 30)
# Out:
# Problem : Shifted Sphere Function
# Dimension : 50
# Best solution vector :
#  [ 98.56860948  77.40633136 -19.80427061  25.36656257 -23.21577486
#   72.53835985   4.32700159  61.98013853 -21.74735244  92.90586784
#  -94.46954921  90.93588412  41.71570272  28.28501656 -11.58573323
#  -66.9252553   66.62292068  94.4791397  -73.05472683 -49.44338673
#   83.85456192  34.78176307  24.43355031   2.95828909 -99.3025178
#  -55.35611551  95.89316764  72.15640877 -99.05349075  -1.80642498
#  -15.86975197  54.93769898  -1.92731718   6.0051585   56.4498195
#   17.96402351 -74.84560894 -80.090525    31.21584383  99.664094
#  -28.56615116 -65.69588562 -87.85823523 -38.16704352 -33.65425408
#  -24.2955833   90.87409681  43.42590913  55.88929855  22.9841344 ]
# Best fitness : [-401.52120565]
# Time of calculation of the best run : 0:00:02.216293
# Total time of calculation (over 10 runs) : 0:00:24.825050

# %% [markdown]
# ### Dimension = 500

# %%
# Running the "best" algorithm and displaying the performance
f1.dim = 500
run_pso(prob_instance = f1, epoch_runs = 5, generations = 5000, 
        inertia = 0.7, 
        self_confidence = 2.0,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Sphere Function
# Dimension : 500
# Best solution vector :
#  [ 9.70394265e+01  7.68210467e+01 -1.83633597e+01  2.48606954e+01
#  -2.30180838e+01  6.95024169e+01  6.21822199e+00  6.15916700e+01
#  -2.16112930e+01  9.25831134e+01 -8.55697840e+01  9.01588030e+01
#   4.23822993e+01  2.94164239e+01 -1.08585853e+01 -6.51754344e+01
#   6.67607941e+01  9.40101317e+01 -7.39045380e+01 -4.79847072e+01
#   8.17869825e+01  3.50661327e+01  2.44274610e+01  2.11796386e+00
#  -9.94213284e+01 -5.46428411e+01  9.59939165e+01  7.20412070e+01
#  -9.69498520e+01 -2.59475142e+00 -1.67347211e+01  5.97184398e+01
#  -2.19753716e+00  4.89109629e+00  4.64089514e+01  1.83667885e+01
#  -7.45255996e+01 -7.87318339e+01  3.24253549e+01  9.89018110e+01
#  -3.02386560e+01 -6.52085277e+01 -8.63519087e+01 -3.86538938e+01
#  -3.31819756e+01 -2.46470486e+01  9.02692613e+01  4.33965249e+01
#   5.64468437e+01  2.32806195e+01  2.96713994e+01  5.10300741e+01
# ...

# %%
# Tuning the parameters
run_pso(prob_instance = f1, epoch_runs = 5, generations = 5000, 
        inertia = 0.4, 
        self_confidence = 2.0,
        swarm_confidence = 2.4, num_individuals_pop = 30)
# Out:
# Problem : Shifted Sphere Function
# Dimension : 500
# Best solution vector :
#  [-1.22605854e+01  7.67117545e+01 -7.75043059e+00  8.81496217e+00
#   5.91806755e+00  6.41106659e+01  7.99416006e+00  4.07675814e+01
#  -2.61054751e+01  7.86286728e+01 -3.02910588e+01  3.91067122e+00
#   4.94337212e+01  7.93637006e+00 -1.40292667e+01 -1.65499233e+01
#   5.29914230e+01  9.73358956e+01 -7.17266367e+01 -4.22224473e+00
#  -7.83009100e+00  4.22469619e+00  2.62398170e+01 -2.78815598e+00
#  -2.88986586e+01 -4.98742408e+01  8.40057113e+01  7.21762857e+01
#   3.57591723e+00 -7.18778190e+00 -2.02684379e+01  5.51655174e+01
#  -1.90425843e+00  4.25056055e+01  8.73483569e+00  3.75689825e+01
#  -7.37003591e+01 -7.71818631e+01  3.10956194e+01  8.84626751e+01
#   9.39662370e+00 -6.60383844e+01 -8.20943213e+01 -3.75401402e+01
#  -3.22007956e+01 -1.28266930e+01  9.04771214e+01  3.58560074e+01
#  -1.29287129e+01 -8.10429586e+00  2.27246449e+01  4.21720713e+01
# ...

# %%
# A test with Genetic Algorithm with the same dimension (D = 50)
run_sga(prob_instance = f1, epoch_runs = 20, generations = 5000, num_individuals_pop = 30)
# Out:
# Problem : Shifted Sphere Function
# Dimension : 500
# Best solution vector :
#  [ 9.65117182e+01  7.87672659e+01 -4.18430178e+00  3.82116789e+01
#  -1.23260919e+01  6.85971186e+01 -5.12892726e+00  6.29832425e+01
#  -2.22184064e+00  8.60895934e+01 -9.89490603e+01  9.42202151e+01
#   3.20771857e+01  5.00609443e+01 -2.45726113e+01 -7.39893608e+01
#   8.39917985e+01  8.83949699e+01 -7.75209717e+01 -4.62937269e+01
#   5.25753073e+01  2.43788520e+01  4.23962860e+01  1.39407278e+01
#  -9.98342003e+01 -5.36102898e+01  8.72943260e+01  7.45710400e+01
#  -9.01625284e+01 -2.05823915e+00 -3.72994221e+01  6.89140962e+01
#  -5.75447834e+00 -6.40178201e+00  2.72868351e+01  4.85854837e+00
#  -9.99844428e+01 -6.67722424e+01  3.24975538e+01  9.95089818e+01
#  -2.59403772e+01 -9.44349641e+01 -9.25236052e+01 -3.25594762e+01
#  -4.15832733e+01 -3.98758893e+01  6.64481004e+01  3.99082977e+01
#   6.42505878e+01  3.44610271e+01  3.10037657e+01  3.25400661e+01
# ...

# %% [markdown]
# ## F2 : shifted Schwefel function

# %%
#Visualisation with a 2D-vector
f2 = shifted_Schwefel(2, sf.schwefel,sf.f_bias[1])
viz_2dim(x_range = 100, y_range = 100, step = 10, prob_instance = f2)

# %%
# Looking for "the best" algorithm
f2.dim = 10
run_algos(prob_instance = f2, generations = 200, num_individuals_pop = 30)

# %% [markdown]
# ### Dimension = 50

# %%
# Running the "best" algorithm and displaying the performance
f2.dim = 50
run_pso(prob_instance = f2, epoch_runs = 10, generations = 1500, 
        inertia = 0.7, 
        self_confidence = 2.0,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Schwebel Function
# Dimension : 50
# Best solution vector :
#  [-29.56335646   4.88945165 -53.72216679 -99.98757994  -8.55696279
#  -60.61690995   7.49009854 -84.27054352 -70.82147689 -51.32631781
#  -51.03946503 -59.78286991 -14.9028513  -38.20838316 -92.20107203
#  -53.2756318  -54.60570735 -46.68294321 -84.40328685 -83.34083961
#  -37.8330138  -85.69253066 -55.61894806 -56.40062247   0.86885141
#  -41.07141699 -11.79980912 -79.67215879 -53.85636779 -56.50805839
#  -77.55509309 -78.55231213 -46.9793148  -58.3381807  -88.27109944
#  -75.67309829 -86.40135609 -63.65248325 -64.21852682 -63.57042459
#   -4.02055192 -67.48485639 -29.84815413 -38.78788306  -1.6657748
#  -75.68448442 -23.40530114 -62.17694467 -36.36264146 -86.66404798]
# Best fitness : [-439.67023561]
# Time of calculation of the best run : 0:00:17.555300
# Total time of calculation (over 10 runs) : 0:02:56.555679

# %%
# Tuning the parameters
run_pso(prob_instance = f2, epoch_runs = 10, generations = 1500, 
        inertia = 0.4, 
        self_confidence = 1.7,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Schwebel Function
# Dimension : 50
# Best solution vector :
#  [-24.27540213   5.01694313 -28.762284   -82.48036107  39.74598129
#   11.4302589   55.11875916  -9.54932317 -28.74373476 -74.55429341
#   10.1055845   21.05524215 -59.46229786  39.29313666 -61.6293429
#  -19.96876021 -62.71450192 -35.37731161 -27.24471044 -19.21713944
#   27.53663003 -94.6150811  -31.687357   -12.09124651  49.06402585
#   11.77386058  53.09186907 -99.92210366 -21.16045072   2.638356
#  -45.41655376 -28.05806916  24.97411683 -79.22791566 -54.55222658
#  -61.81754886 -21.28482084  14.05949919 -45.60734407 -28.92181313
#  -79.48770143 -99.99394431  32.39069163   3.52617348 -14.10255532
#  -16.08706016   3.2109777  -74.8424124  -26.77713623  -8.15084757]
# Best fitness : [-374.65716478]
# Time of calculation of the best run : 0:00:16.721334
# Total time of calculation (over 10 runs) : 0:10:20.064566

# %% [markdown]
# ### Dimension = 500

# %%
# Running the "best" algorithm and displaying the performance
f2.dim = 500
run_pso(prob_instance = f2, epoch_runs = 5, generations = 3000, 
        inertia = 0.7, 
        self_confidence = 2.0,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Schwebel Function
# Dimension : 500
# Best solution vector :
#  [ -70.81128832   91.76288309  -72.83707761  -11.12218884  100.
#    33.13266425    7.97939096   20.70099544  -99.25405119   -0.81121363
#    24.50851865   -1.50437679  -99.95516394   75.82829209  -37.04074211
#   -21.5223855    25.33893895   25.7708574   -37.41507379  -98.92721029
#  -100.          -15.91782887  -40.27198077  -99.60797131  -99.39913633
#   -97.1485373   -57.95195592  -41.48560583  -27.37854117   21.86446746
#     4.89254636 -100.          -12.44848352   44.44289663   -1.01264188
#    33.2891028    -6.48301244   25.83039287  -99.99969321   54.72771484
#   -53.9816803   -88.08636963   52.41679132  -84.28033055   53.5277086
#    18.17652497    6.21744152   30.05554955    8.10759131  -99.99998948
#     0.80532551   -0.36048966   55.03074735 -100.          -74.93824706
#  -100.          -14.81229601   23.44292474  -99.59940747   72.95048767
# ...

# %%
# Tuning the parameters
run_pso(prob_instance = f2, epoch_runs = 5, generations = 3000, 
        inertia = 0.5, 
        self_confidence = 1.8,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Schwebel Function
# Dimension : 500
# Best solution vector :
#  [ -53.99439031  -21.15862501   30.91941156  -99.60278349    4.30849149
#   -99.95559227  -17.66018522  -99.9897986    -3.33446273    7.7847408
#   -74.02777654   56.43949802   19.17138147  -99.99984161  -15.50793088
#   -43.61621986  -99.77352057   20.02742804  -58.28584768  -99.9998613
#    68.31136143    8.30823977   -2.25343271  -13.51298638    5.29328902
#    83.31953209    6.62413631   43.16633212  -74.7989248   -96.38431272
#    23.38669706  -96.33177921   -8.75255192  -10.16050375  -10.98165771
#   -26.42780506    2.66780172  -37.98545629  -28.52141595   -8.35378021
#   -16.95797204   25.1726697   -99.95491206   49.61613462  -84.33298152
#   -94.92680688  -81.12614575   15.26771895  -98.27280586  -33.8952005
#     8.91590366  -59.06214143   36.70330381   60.97935978   39.57333234
#   -34.89102011  -98.27547616  -53.84168632   78.36126297   73.5205801
# ...

# %% [markdown]
# ## F3 : shifted Rosenbrock function

# %%
#Visualisation with a 2D-vector
f3 = shifted_Rosenbrock(2, sf.rosenbrock,sf.f_bias[2])
viz_2dim(x_range = 100, y_range = 100, step = 10, prob_instance = f3)

# %%
# Looking for "the best" algorithm
f3.dim = 10
run_algos(prob_instance = f3, generations = 200, num_individuals_pop = 30)

# %% [markdown]
# ### Dimension = 50

# %%
# Running the "best" algorithm and displaying the performance
f3.dim = 50
run_pso(prob_instance = f3, epoch_runs = 10, generations = 2000, 
        inertia = 0.7, 
        self_confidence = 2.0,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Rosenbrock Function
# Dimension : 50
# Best solution vector :
#  [-77.33520726 -35.90025367 -57.9005795   38.40002239  51.5000018
#  -31.28848893  49.7082047   48.81414075 -72.14292333 -31.77256489
#  -43.98839547 -21.0829282   70.53778324  47.03390412 -47.019067
#   -9.1485717  -41.9621701  -14.81545816  34.8262358   56.1481753
#   57.59952685 -18.39718202  26.30039056 -63.55224423 -29.8101484
#  -87.51719821  47.30825161  -8.57135299 -83.15122509 -73.06887191
#   81.25615369  18.5984769  -46.57351166  76.32954421 -13.60239924
#  -82.17599072  71.88862554  85.0925045   27.41257109  39.85994067
#   -3.0317082   32.45400503 -25.66168779 -18.81048167   1.59508553
#  -82.79793468  87.45423628 -35.26416297 -44.82476065  18.82294678]
# Best fitness : [435.41547422]
# Time of calculation of the best run : 0:00:43.832592
# Total time of calculation (over 10 runs) : 0:07:17.815713

# %%
# Tuning the parameters
run_pso(prob_instance = f3, epoch_runs = 10, generations = 2000, 
        inertia = 0.7, 
        self_confidence = 2.0,
        swarm_confidence = 2.3, num_individuals_pop = 30)
# Out:
# Problem : Shifted Rosenbrock Function
# Dimension : 50
# Best solution vector :
#  [-77.42940856 -35.73188722 -57.59771972  38.90572835  52.24304778
#  -30.36494447  50.68371595  49.78324633 -71.18147439 -30.82954134
#  -43.0902264  -20.24314232  71.25083872  47.55154517 -46.74278585
#   -9.07490531 -41.95578415 -14.81628777  34.83009997  56.14768951
#   57.59313183 -18.40745308  26.29779328 -63.55256506 -29.81176048
#  -87.52087624  47.30559346  -8.56132475 -83.13590638 -73.0731565
#   81.25902315  18.59813364 -46.57571593  76.33000639 -13.60133549
#  -82.17767011  71.88308098  85.09621138  27.40921656  39.86642561
#   -3.03147626  32.44734349 -25.65754363 -18.80917462   1.59282042
#  -82.79519168  87.44752519 -35.26029515 -44.82135676  18.8267378 ]
# Best fitness : [425.43538601]
# Time of calculation of the best run : 0:00:45.409646
# Total time of calculation (over 10 runs) : 0:07:22.830836

# %% [markdown]
# ### Dimension = 500

# %%
# Running the "best" algorithm and displaying the performance
f3.dim = 500
run_pso(prob_instance = f3, epoch_runs = 10, generations = 1500, 
        inertia = 0.7, 
        self_confidence = 2.0,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Rosenbrock Function
# Dimension : 500
# Best solution vector :
#  [-7.67978450e+01 -3.94789399e+01 -4.71761175e+01  2.18447371e+01
#   6.24278975e+01 -8.49622777e+00  3.97448725e+01  4.10055769e+01
#  -2.83896368e+01 -4.08027340e+01 -3.48626244e+01 -1.91417980e+00
#   5.49421998e+01  5.59342119e+01 -3.04848415e+01  5.73505086e+00
#  -5.45754184e+01 -2.43571556e+01  5.81793288e+01  5.00821150e+01
#   5.19840601e+01 -1.37304139e+01  1.45186007e+01 -4.16606981e+01
#  -1.40422250e+01 -9.98951419e+01  5.51996000e+01 -2.76299962e+01
#  -9.92934486e+01 -6.12894125e+01  6.66621833e+01  5.61404120e+01
#  -2.77483049e+01  9.95510005e+01 -1.83479077e+00 -9.96514240e+01
#   7.32336906e+01  6.05186228e+01  2.32790586e+01  3.54890210e+01
#   2.21594251e+01  2.96091359e+01  1.29419776e-01 -1.79180631e+01
#  -3.00052281e+00 -8.18427945e+01  7.32079175e+01 -5.54089790e+01
#  -2.05572719e+01  9.34761526e+00  4.21777791e+00 -2.78626219e+01
# ...

# %%
# Tuning the parameters
run_pso(prob_instance = f3, epoch_runs = 10, generations = 1500, 
        inertia = 0.7, 
        self_confidence = 1.5,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Rosenbrock Function
# Dimension : 500
# Best solution vector :
#  [-55.98654182 -38.06916767 -69.59092035  32.90210556  66.96866933
#  -28.27558951  13.07088055  77.18871113 -33.66711072 -71.50103287
#  -55.02711651 -14.25840215  66.6353395   65.56179648 -51.5499955
#   21.72158819 -55.76541244  -8.48174028  38.37888622  64.98750388
#   56.73563948 -26.46573469  25.24547543 -28.85123157 -22.07252328
#  -92.30800027  36.96491634   2.78962415 -68.89494236 -95.30159905
#   75.86109788  18.4122111  -45.49883499  68.47072274   7.98834055
#  -72.90878454  54.14501158  73.80562898  13.40138962  51.94568046
#    0.39744498  20.27603006 -36.00674152 -19.73834042 -29.50035691
#  -94.63457282  88.89027464 -51.99796641 -36.08379641  12.63852165
#   -2.06289765 -30.89555931 -23.41366855  47.09339883 -90.16346118
#  -35.82317388  39.89445791 -89.09750319  60.47231494  -6.59851107
#   29.49203023 -47.05781497  -1.28672292  74.54827437  63.10097937
# ...

# %% [markdown]
# ## F4: shifted Rastrigin function

# %%
#Visualisation with a 2D-vector
f4 = shifted_Rastrigin(2, sf.rastrigin,sf.f_bias[3])
viz_2dim(x_range = 5.1, y_range = 5.1, step = 0.05, prob_instance = f4)

# %%
# Looking for "the best" algorithm
f4.dim = 10
run_algos(prob_instance = f4, generations = 200, num_individuals_pop = 30)

# %% [markdown]
# ### Dimension = 50

# %%
# Running the "best" algorithm and displaying the performance : Bee colonny
f4.dim = 50
run_abc(prob_instance = f4, epoch_runs = 10, generations = 2000, 
        limit = 20, num_individuals_pop = 30)
# Out:
# Problem : Shifted Rastrigin Function
# Dimension : 50
# Best solution vector :
#  [-0.01823123  4.50287139  2.15420566  1.68119404 -3.46074404  2.42633405
#   1.32525284  1.94119232  4.17966776  0.9252472  -3.42197633 -0.11587234
#   0.77012064  4.24186283  3.58384028 -2.53992167 -4.6753637   3.35908142
#  -1.98447143 -0.03937883  1.94020024 -2.29923584 -1.51960361  1.77575095
#  -3.64853637  1.59339275  1.50085166  1.52463097  0.80758491  4.96835676
#  -3.46664449  1.72531228 -0.86457251 -3.22649369 -1.43278944 -3.44290581
#  -4.79780151  1.98430114  0.21630493 -1.18655572  2.90943704  2.84907196
#   3.96577417  3.50756414 -2.23738641  3.05656092 -2.77164372 -1.32903002
#   3.98140923 -2.14179624]
# Best fitness : [701.61648919]
# Time of calculation of the best run : 0:00:24.704672
# Total time of calculation (over 10 runs) : 0:04:05.046363

# %%
# Running with another potentially "best" algorithm: Self-adative Differential Evolution
run_sade(prob_instance = f4, epoch_runs = 10, generations = 2000, 
        f_tolerance = 1e-6, num_individuals_pop = 30)
# Out:
# Problem : Shifted Rastrigin Function
# Dimension : 50
# Best solution vector :
#  [ 3.84659386  4.32362266 -2.82162996  0.64653623  4.33820181  2.44086973
#  -3.45930672  2.33705838  3.97997814  4.29001075  2.37393303  3.22497382
#  -0.02357693  4.62738539  4.61343311  0.99472235  1.61013711 -4.72535068
#  -2.69746704  1.03554146 -3.2047909   3.80570522 -2.67825442 -3.22904566
#   4.41155046  0.715884   -4.42193963  1.49159561  0.73886487  2.17939092
#  -3.27775478  2.78361497  3.59619002 -4.71921159  0.51737183 -3.60436048
#  -3.20398593  0.46834683 -2.03018591 -0.39847461 -3.77110847  4.96803241
#   4.32144658  3.35468402 -4.86572683  4.83207027  0.21250467 -4.27498109
#   3.68403273  4.78742853]
# Best fitness : [-329.99999993]
# Time of calculation of the best run : 0:00:28.084834
# Total time of calculation (over 10 runs) : 0:04:52.336047

# %%
# A test with PSO
run_pso(prob_instance = f4, epoch_runs = 10, generations = 2000,
        inertia = 0.7, 
        self_confidence = 2.0,
        swarm_confidence = 2.0, 
        num_individuals_pop = 30)
# Out:
# Problem : Shifted Rastrigin Function
# Dimension : 50
# Best solution vector :
#  [ 3.8466369   4.32362288 -2.82163073  4.62632052  4.33820486  1.44591294
#  -2.46435613  4.3269709   4.97494154  4.2900153   3.36889348  2.23001867
#  -2.01348412  1.64253079  3.6184827   1.9896817   0.61518249 -4.7253486
#  -2.69746284 -0.95436274 -4.19975407  3.80570155 -0.68834328 -3.22904675
#   3.41659329  1.71084428 -4.4219373   1.49160958 -0.25609206  0.18948246
#  -1.28784771  1.78866091  3.59618783 -3.72424399 -1.47254034 -4.59931968
#  -0.21912564  1.46328952 -3.02514766 -0.398475   -4.76606811  3.97307942
#   4.32145019  1.36476355 -4.86572224  2.8421619   3.19736221 -3.28001598
#   1.69411759  4.78742782]
# Best fitness : [-227.51945891]
# Time of calculation of the best run : 0:00:29.749079
# Total time of calculation (over 10 runs) : 0:05:07.006406

# %% [markdown]
# ### Dimension = 500

# %%
# Running the "best" algorithm and displaying the performance
f4.dim = 500
run_abc(prob_instance = f4, epoch_runs = 5, generations = 10000, 
        limit = 20, num_individuals_pop = 30)
# Out:
# Problem : Shifted Rastrigin Function
# Dimension : 500
# Best solution vector :
#  [ 3.82755191e+00  7.15258039e-01  1.42020367e+00 -2.97584257e+00
#   2.92540830e+00 -4.21217793e+00  2.06108380e+00 -4.81118090e+00
#   1.25144834e+00  1.43196999e+00  3.32896860e+00 -3.03262713e+00
#   4.24921644e+00  3.70192113e+00  2.91542458e+00  4.26743636e+00
#  -4.57413859e+00 -6.25339867e-02 -1.20811660e+00 -8.97860858e-03
#  -7.97735232e-02  4.05868513e+00  1.97038759e+00 -3.78322719e+00
#   3.52975845e+00  2.47551805e+00 -3.89158115e+00 -4.77714216e+00
#   3.04495248e+00  1.09769258e+00  2.29926428e+00  1.05003662e+00
#   1.18526623e+00 -2.36084548e-01 -2.75019047e+00  2.34425282e+00
#  -3.31530985e+00  1.66077155e+00 -3.95064962e+00  3.37263515e+00
#  -3.64272692e+00  1.18910788e+00  4.44658849e+00 -1.10884628e-01
#   4.27919807e+00  3.35532475e+00  3.18882365e+00 -4.01016394e+00
#   5.84526686e-01  2.87204660e+00  2.25968485e+00  2.49405203e+00
# ...

# %%
# Running Self-adative Differential Evolution algorithm
run_sade(prob_instance = f4, epoch_runs = 5, generations = 10000, 
        f_tolerance = 1e-6, num_individuals_pop = 30)
# Out:
# Problem : Shifted Rastrigin Function
# Dimension : 500
# Best solution vector :
#  [ 3.85357576e+00  4.31382639e+00 -2.81957282e+00  6.95039039e-01
#   4.35970698e+00  2.41418064e+00 -3.46709691e+00  2.31613341e+00
#   2.97423517e+00  4.28278682e+00  2.38302924e+00  3.22368554e+00
#  -1.04896808e-02  4.63210578e+00  4.61391173e+00  9.96397425e-01
#   1.59702286e+00 -4.72604940e+00 -2.70240391e+00  1.00911504e+00
#  -3.20632793e+00  3.77581392e+00 -2.67614097e+00 -3.22480572e+00
#   4.38043181e+00  1.69485103e+00 -4.42137205e+00  1.49668223e+00
#   7.57669522e-01  2.18300971e+00 -3.27805464e+00  2.80096589e+00
#   3.59807457e+00 -4.68579152e+00  5.24283635e-01 -3.57180897e+00
#  -3.20041591e+00  4.57480721e-01 -2.01907663e+00 -3.96422177e-01
#  -3.77319455e+00  3.97684103e+00  4.32463702e+00  3.42158078e+00
#  -4.85077953e+00  4.83276564e+00  2.15593614e-01 -4.27414417e+00
#   3.69466011e+00  4.78478684e+00 -4.08345412e+00  3.42084885e+00
# ...

# %% [markdown]
# ## F5 : shifted Griewank function

# %%
#Visualisation with a 2D-vector
f5 = shifted_Griewank(2, sf.griewank,sf.f_bias[4])
viz_2dim(x_range = 600, y_range = 600, step = 10, prob_instance = f5)

# %%
# Looking for "the best" algorithm
f5.dim = 10
run_algos(prob_instance = f5, generations = 200, num_individuals_pop = 30)

# %% [markdown]
# ### Dimension = 50

# %%
# Running the "best" algorithm and displaying the performance
f5.dim = 50
run_pso(prob_instance = f5, epoch_runs = 10, generations = 2000, 
        inertia = 0.7, 
        self_confidence = 2.0,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Griewank Function
# Dimension : 50
# Best solution vector :
#  [ 555.86299957 -278.20600085   84.68172992  -16.82123052  511.70480188
#   329.90553629  -52.23884681 -595.56521833  404.53580864  -86.22228451
#   138.51872243  361.20525395  517.50047369  285.84840416 -364.1515497
#  -113.15272775  522.56361202  500.28586586 -121.36482857  472.37946893
#  -544.92233964 -176.55848117  375.79970857 -588.16663488 -433.33146803
#  -356.68163324 -361.53366705   91.32468151 -273.37438125 -361.42299774
#  -581.67106053  296.14291644  -65.88431412  518.17707892  -40.80669134
#   -97.62035182  415.46560254   30.18313306 -356.82349774  166.90595397
#   405.74182372 -576.4324747   217.5324854  -144.62283997  398.15474951
#     3.37590203  251.36482462  -85.32795533 -234.46332066  558.47238195]
# Best fitness : [-8811.22284866]
# Time of calculation of the best run : 0:01:02.798188
# Total time of calculation (over 10 runs) : 0:11:08.488180

# %%
# Tuning the parameters
run_pso(prob_instance = f5, epoch_runs = 10, generations = 2000, 
        inertia = 1.0, 
        self_confidence = 2.0,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Griewank Function
# Dimension : 50
# Best solution vector :
#  [ 598.39347516 -499.94956962  287.16751587 -217.24724254  600.
#   600.           87.55465727 -565.53738772  465.2612268  -223.71547902
#     9.34022524  133.39603406  600.           -8.06704049 -343.72015954
#  -369.3975363   600.          587.5657765  -201.24441322  375.59359464
#  -600.         -240.48831117  481.05363613 -353.77595746 -600.
#  -600.         -194.98375168  332.26302467    0.         -427.63859189
#  -600.          108.37576879  -68.06429035  594.49273819    7.78444484
#   -16.48052198  572.24870673   47.18968329 -589.05319921   90.93782822
#   600.         -523.96697649  349.64302959  -90.45106606  600.
#  -320.66505181  122.72817471  -15.07117827  -27.69955523 -240.61604856]
# Best fitness : [-8462.76266522]
# Time of calculation of the best run : 0:01:12.417607
# Total time of calculation (over 10 runs) : 0:11:28.524820

# %% [markdown]
# ### Dimension = 500

# %%
# Running the "best" algorithm and displaying the performance
f5.dim = 500
run_pso(prob_instance = f5, epoch_runs = 5, generations = 1000, 
        inertia = 0.7, 
        self_confidence = 2.0,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Griewank Function
# Dimension : 500
# Best solution vector :
#  [ 5.04660991e+02 -2.78516609e+02  1.17731614e+02 -1.59744208e+01
#   4.47444664e+02  3.29753010e+02 -4.32354147e+00 -5.88497765e+02
#   4.57478517e+02 -7.15835784e+01  1.76372761e+02  3.85987669e+02
#   4.98423175e+02  1.84203572e+02 -4.02241818e+02 -1.34305710e+02
#   5.46113044e+02  5.70348835e+02 -1.75171062e+02  4.73335417e+02
#  -4.29563479e+02 -2.44930282e+02  3.52748388e+02 -4.68738688e+02
#  -4.71630226e+02 -3.40071524e+02 -3.57947892e+02  1.12172916e+02
#  -1.39729538e+02 -5.11266720e+02 -5.80708241e+02  2.53990496e+02
#  -5.36689832e+01  4.62054654e+02  1.66777253e+01 -1.07280980e+02
#   4.43742131e+02  6.13878714e+01 -4.26454110e+02  2.28281555e+02
#   3.01690963e+02 -4.66459513e+02  1.47394231e+02 -2.07845590e+02
#   3.85959938e+02 -1.53615698e+01  2.15167597e+02 -5.60456007e+01
#  -7.14690944e+01 -3.44398387e+02 -3.63407473e+02  6.22616420e+01
# ...

# %%
# Tuning the parameters
run_pso(prob_instance = f5, epoch_runs = 5, generations = 1000, 
        inertia = 0.7, 
        self_confidence = 1.5,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Griewank Function
# Dimension : 500
# Best solution vector :
#  [ 5.67881625e+02 -3.35050047e+02  1.44558128e+02 -8.60875293e+01
#   3.42156728e+02  3.19175552e+02  4.13188139e+01 -5.00259584e+02
#   3.31137035e+02 -6.22059832e+01  1.06448946e+02  5.13546125e+02
#   5.90091550e+02  2.87412363e+02 -3.97709435e+02 -1.43030243e+02
#   3.63333330e+02  5.10922280e+02 -9.81684297e+00  5.02058438e+02
#  -5.13334087e+02 -1.97228574e+02  3.14874345e+02 -5.71787891e+02
#  -4.87813256e+02 -2.80869779e+02  2.57874263e+02  1.58591791e+02
#  -2.35278235e+02 -4.54198264e+02 -5.07336435e+02  3.59814884e+02
#  -1.42844471e+01  4.89956308e+02  1.21722684e+01 -7.68503381e+01
#   3.30531514e+02  1.21046833e+02 -3.67683406e+02  1.85801040e+02
#   3.64985147e+02 -4.83725142e+02  2.08287154e+02 -1.53929080e+02
#   4.17403704e+02  1.16338899e+01  8.00044028e+01 -3.44443737e+01
#  -2.64489701e+02 -3.67282486e+02 -2.24173862e+02  1.94694301e+02
# ...

# %% [markdown]
# ## F6 : shifted Ackley function

# %%
# Visualisation with a 2D-vector
f6 = shifted_Ackley(2, sf.ackley,sf.f_bias[5])
viz_2dim(x_range = 33, y_range = 33, step = 0.95, prob_instance = f6)

# %%
# Looking for "the best" algorithm
f6.dim = 10
run_algos(prob_instance = f6, generations = 200, num_individuals_pop = 30)

# %% [markdown]
# ### Dimension = 50

# %%
# Running the "best" algorithm and displaying the performance
f6.dim = 50
run_pso(prob_instance = f6, epoch_runs = 10, generations = 2000, 
        inertia = 0.7, 
        self_confidence = 2.0,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Ackley Function
# Dimension : 50
# Best solution vector :
#  [ 27.00775711 -16.13168919   6.41055501  -0.84105188  23.47793797
#   15.72580998  -2.61194009 -28.88978141  19.28442986  -3.31779814
#    6.92594089  17.51622225  25.30877824  14.29243475 -19.42403133
#   -5.65762722  26.12818195  25.01426639  -5.38378758  23.61897185
#  -26.52652171  -8.82791207  18.78998984 -29.40832196 -21.66654708
#  -17.83408689 -18.07669544   6.22754875 -13.6687245  -18.07114393
#  -29.08356438  14.80714059  -3.29421406  25.90887471  -2.0403395
#   -4.88103194  20.77328507   1.50914978 -17.84115854  10.32824811
#   20.2871067  -28.82162917  10.87662968  -7.23113892  19.90776106
#    0.16877304  12.56828356  -4.26645808 -11.72295799 -18.62077515]
# Best fitness : [-140.]
# Time of calculation of the best run : 0:00:26.796924
# Total time of calculation (over 10 runs) : 0:05:26.260123

# %%
# Tuning the parameters
run_pso(prob_instance = f6, epoch_runs = 10, generations = 2000, 
        inertia = 0.7, 
        self_confidence = 2.0,
        swarm_confidence = 2.3, num_individuals_pop = 30)
# Out:
# Problem : Shifted Ackley Function
# Dimension : 50
# Best solution vector :
#  [ 27.00775612 -16.13168903   6.41055502  -0.84105175  23.47793784
#   15.72580971  -2.61194014 -28.88978075  19.28443004  -3.31779831
#    6.92594209  17.51622286  25.30877793  14.29243497 -19.42403192
#   -5.65762691  26.12818079  25.01426525  -5.38378733  23.61897127
#  -26.52652278  -8.8279116   18.78998866 -29.40832268 -21.66654813
#  -17.83408648 -18.07669519   6.22754953 -13.66872474 -18.07114502
#  -29.08356526  14.80714139  -3.29421475  25.90887501  -2.04033927
#   -4.88103198  20.77328592   1.50915043 -17.8411588   10.32824879
#   20.28710711 -28.82162894  10.87663017  -7.23113856  19.9077621
#    0.16877314  12.56828301  -4.26645605 -11.72295825 -18.62077531]
# Best fitness : [-139.99999726]
# Time of calculation of the best run : 0:00:27.199071
# Total time of calculation (over 10 runs) : 0:05:05.815846

# %% [markdown]
# ### Dimension = 500

# %%
# Running the "best" algorithm and displaying the performance
f6.dim = 500
run_pso(prob_instance = f6, epoch_runs = 5, generations = 8000, 
        inertia = 0.7, 
        self_confidence = 2.0,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Ackley Function
# Dimension : 500
# Best solution vector :
#  [ 1.30174948e+01 -2.13118087e-02  9.96099813e+00 -1.48370337e+01
#   3.49210898e+00  4.79358833e+00  2.38752319e+00 -2.60636310e+01
#   6.29519146e+00 -7.31349231e+00  6.92754928e+00  2.25182283e+01
#   2.52952914e+01 -2.07054486e+01 -7.44912278e+00 -1.26481442e+01
#   4.13075815e+00  2.10162276e+01  3.09663128e-01  1.06338749e+01
#  -2.25371211e+01  2.16051640e+00  1.26815293e+01 -2.44054364e+01
#  -2.46871780e+01 -2.81249901e+00 -3.10858075e+01  3.22552765e+00
#  -5.68702516e+00 -7.10764955e+00  1.14942945e+01  3.81322196e+00
#   6.52981861e-01  1.79929462e+01 -1.04034663e+00  1.51382721e+01
#  -4.27329155e+00 -5.12608543e-01 -1.98318230e+01  3.34900612e+00
#   1.52865134e+01 -1.48263564e+01  1.58647080e+01 -8.23086005e+00
#   3.09071077e+01  1.01627683e+01  4.56375263e+00 -8.26469124e+00
#  -8.71900474e+00 -7.62101113e+00 -1.37852874e+00 -2.06877487e+00
# ...

# %%
# Tuning the parameters
run_pso(prob_instance = f6, epoch_runs = 5, generations = 8000, 
        inertia = 0.7, 
        self_confidence = 1.7,
        swarm_confidence = 2.0, num_individuals_pop = 30)
# Out:
# Problem : Shifted Ackley Function
# Dimension : 500
# Best solution vector :
#  [ 13.00713111   3.8284162   22.26120617   7.16233915   6.48472114
#   22.71768334   8.4002219  -10.8748855    8.26726428   3.73883862
#   21.92156601  -7.10850504  16.30872195  27.2891433   -6.40460915
#   -4.66004943   8.13036895  22.00777392  -2.37995076  -1.38595871
#  -30.51102926   2.17435393  21.78378788 -15.3739398    4.35302617
#   -0.83272725 -13.08375557  -6.79479472 -15.66742471 -18.07967557
#   17.91487846  10.81086431  -3.28662824  -0.0773552    2.98823334
#   -4.87856639  14.75902603  15.49953619 -15.85380961  -3.68111643
#   -5.69919173  -6.81538109  21.91696046   8.77100869  -2.07222298
#   -6.82484921  19.60018846  17.05830201 -12.72810798 -21.62116294
#    7.60795205   0.8185819  -12.8799711    3.49457345  16.03853235
#   -7.11999191  13.70790514  15.60996334  12.22050223   1.63575238
#   12.73897163  25.98296667  18.29236761  -2.29233186  15.05747702
# ...
